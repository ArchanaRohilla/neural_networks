# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/100
# 576/576 [==============================] - 0s 722us/sample - loss: 0.6989 - accuracy: 0.5521
# Epoch 2/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.6557 - accuracy: 0.6198
# Epoch 3/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.6228 - accuracy: 0.6562
# Epoch 4/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5961 - accuracy: 0.7101
# Epoch 5/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.5768 - accuracy: 0.7309
# Epoch 6/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5602 - accuracy: 0.7378
# Epoch 7/100
# 576/576 [==============================] - 0s 50us/sample - loss: 0.5462 - accuracy: 0.7378
# Epoch 8/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5343 - accuracy: 0.7517
# Epoch 9/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5246 - accuracy: 0.7587
# Epoch 10/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.5159 - accuracy: 0.7674
# Epoch 11/100
# 576/576 [==============================] - 0s 50us/sample - loss: 0.5084 - accuracy: 0.7656
# Epoch 12/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.5013 - accuracy: 0.7726
# Epoch 13/100
# 576/576 [==============================] - 0s 50us/sample - loss: 0.4951 - accuracy: 0.7812
# Epoch 14/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4897 - accuracy: 0.7865
# Epoch 15/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4848 - accuracy: 0.7934
# Epoch 16/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4804 - accuracy: 0.7917
# Epoch 17/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4772 - accuracy: 0.7934
# Epoch 18/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4733 - accuracy: 0.7969
# Epoch 19/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4706 - accuracy: 0.7986
# Epoch 20/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4677 - accuracy: 0.8021
# Epoch 21/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4656 - accuracy: 0.8038
# Epoch 22/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4630 - accuracy: 0.8038
# Epoch 23/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4610 - accuracy: 0.8038
# Epoch 24/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4593 - accuracy: 0.8003
# Epoch 25/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4573 - accuracy: 0.8021
# Epoch 26/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4557 - accuracy: 0.8021
# Epoch 27/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4544 - accuracy: 0.8038
# Epoch 28/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4529 - accuracy: 0.8038
# Epoch 29/100
# 576/576 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.87 - 0s 59us/sample - loss: 0.4518 - accuracy: 0.8056
# Epoch 30/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4507 - accuracy: 0.8038
# Epoch 31/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4496 - accuracy: 0.8038
# Epoch 32/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4486 - accuracy: 0.8021
# Epoch 33/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4478 - accuracy: 0.8021
# Epoch 34/100
# 576/576 [==============================] - 0s 48us/sample - loss: 0.4467 - accuracy: 0.8003
# Epoch 35/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4459 - accuracy: 0.8003
# Epoch 36/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4454 - accuracy: 0.8021
# Epoch 37/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4441 - accuracy: 0.8003
# Epoch 38/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4433 - accuracy: 0.7986
# Epoch 39/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4428 - accuracy: 0.7951
# Epoch 40/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4420 - accuracy: 0.7986
# Epoch 41/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4415 - accuracy: 0.7986
# Epoch 42/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4407 - accuracy: 0.7986
# Epoch 43/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4400 - accuracy: 0.7986
# Epoch 44/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4392 - accuracy: 0.7986
# Epoch 45/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4388 - accuracy: 0.7969
# Epoch 46/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4378 - accuracy: 0.7951
# Epoch 47/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4370 - accuracy: 0.7934
# Epoch 48/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4366 - accuracy: 0.7917
# Epoch 49/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4357 - accuracy: 0.7917
# Epoch 50/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4353 - accuracy: 0.7917
# Epoch 51/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4346 - accuracy: 0.7917
# Epoch 52/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4337 - accuracy: 0.7899
# Epoch 53/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4332 - accuracy: 0.7882
# Epoch 54/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4325 - accuracy: 0.7865
# Epoch 55/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4321 - accuracy: 0.7865
# Epoch 56/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4315 - accuracy: 0.7882
# Epoch 57/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4311 - accuracy: 0.7865
# Epoch 58/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4301 - accuracy: 0.7882
# Epoch 59/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4300 - accuracy: 0.7865
# Epoch 60/100
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4290 - accuracy: 0.7865
# Epoch 61/100
# 576/576 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.81 - 0s 42us/sample - loss: 0.4286 - accuracy: 0.7847
# Epoch 62/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4281 - accuracy: 0.7882
# Epoch 63/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4279 - accuracy: 0.7865
# Epoch 64/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4270 - accuracy: 0.7882
# Epoch 65/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4265 - accuracy: 0.7899
# Epoch 66/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4266 - accuracy: 0.7899
# Epoch 67/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4258 - accuracy: 0.7882
# Epoch 68/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4250 - accuracy: 0.7917
# Epoch 69/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4247 - accuracy: 0.7899
# Epoch 70/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4241 - accuracy: 0.7882
# Epoch 71/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4235 - accuracy: 0.7899
# Epoch 72/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4230 - accuracy: 0.7899
# Epoch 73/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4231 - accuracy: 0.7917
# Epoch 74/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4227 - accuracy: 0.7934
# Epoch 75/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4217 - accuracy: 0.7899
# Epoch 76/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4212 - accuracy: 0.7917
# Epoch 77/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4208 - accuracy: 0.7917
# Epoch 78/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4203 - accuracy: 0.7934
# Epoch 79/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4200 - accuracy: 0.7934
# Epoch 80/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4197 - accuracy: 0.7917
# Epoch 81/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4189 - accuracy: 0.7969
# Epoch 82/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4188 - accuracy: 0.7934
# Epoch 83/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4183 - accuracy: 0.7951
# Epoch 84/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4177 - accuracy: 0.7969
# Epoch 85/100
# 576/576 [==============================] - 0s 43us/sample - loss: 0.4177 - accuracy: 0.7951
# Epoch 86/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4169 - accuracy: 0.7969
# Epoch 87/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4162 - accuracy: 0.7986
# Epoch 88/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4160 - accuracy: 0.7986
# Epoch 89/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4158 - accuracy: 0.7969
# Epoch 90/100
# 576/576 [==============================] - 0s 40us/sample - loss: 0.4154 - accuracy: 0.8003
# Epoch 91/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4150 - accuracy: 0.8003
# Epoch 92/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4147 - accuracy: 0.8021
# Epoch 93/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4146 - accuracy: 0.7986
# Epoch 94/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4146 - accuracy: 0.8021
# Epoch 95/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4138 - accuracy: 0.7986
# Epoch 96/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4130 - accuracy: 0.8003
# Epoch 97/100
# 576/576 [==============================] - 0s 42us/sample - loss: 0.4128 - accuracy: 0.8003
# Epoch 98/100
# 576/576 [==============================] - 0s 35us/sample - loss: 0.4125 - accuracy: 0.8021
# Epoch 99/100
# 576/576 [==============================] - 0s 38us/sample - loss: 0.4120 - accuracy: 0.8003
# Epoch 100/100
# 576/576 [==============================] - 0s 36us/sample - loss: 0.4118 - accuracy: 0.8003
# 192/192 - 0s - loss: 0.4923 - accuracy: 0.7396
# Loss: 0.4922872334718704, Accuracy: 0.7395833134651184
